# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa

# %%
def get_spectogram(audio_path):
    audio_time, sampling_rate = librosa.load(audio_path)
    
    spectogram = librosa.feature.melspectrogram(y=audio_time, sr=sampling_rate, fmax=1024)
    spectogram_dB = librosa.power_to_db(spectogram, ref=np.max)
    return spectogram_dB, sampling_rate


def display_spectogram(audio_path):
    spectogram_dB, sampling_rate = get_spectogram(audio_path)

    plt.figure(figsize=(5, 4))
    librosa.display.specshow(spectogram_dB, sr=sampling_rate, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel-frequency Spectrogram')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)e')
    plt.tight_layout()
    plt.show()

def display_spectogram_numpy(numpy_path, sr=22050):
    data = np.load(numpy_path)
    print(data)
    plt.figure(figsize=(5, 4))
    librosa.display.specshow(data, sr=sr, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel-frequency Spectrogram')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)e')
    plt.tight_layout()
    plt.show()

# %%
display_spectogram('train6.wav')
display_spectogram_numpy('./spectrogram.npy')
# Out:
# [[-37.668385 -34.633636 -35.63701  ... -36.28872  -33.770046 -33.549545]
#  [-34.54901  -28.247448 -26.736418 ... -27.275078 -26.127947 -28.079065]
#  [-36.960453 -28.74328  -25.798317 ... -25.55997  -25.612059 -27.551756]
#  ...
#  [-61.927254 -56.804348 -60.77864  ... -80.       -80.       -80.      ]
#  [-62.2482   -57.34088  -61.888916 ... -80.       -80.       -80.      ]
#  [-63.11525  -57.74133  -61.252567 ... -80.       -80.       -80.      ]]
